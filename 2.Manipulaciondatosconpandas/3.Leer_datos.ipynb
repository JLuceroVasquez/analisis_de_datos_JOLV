# %%
#Instalamos la librerias
#SQLAlchemy==2.0.29
#mysql-connector-python==8.3.0
#mysqlclient==2.2.4
# !pip install SQLAlchemy==2.0.29 mysql-connector-python==8.3.0 mysqlclient==2.2.4
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 60.4 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.7/626.7 kB 5.2 MB/s eta 0:00:00
# ...
#   Created wheel for mysqlclient: filename=mysqlclient-2.2.4-cp312-cp312-linux_x86_64.whl size=135983 sha256=0277e345d1562bb7bfbf154593e7099ff3caff236ab9e5dae8a2e1e0f711f1f0
#   Stored in directory: /home/codespace/.cache/pip/wheels/20/6f/c3/3b23bb01988b1c0bea0668e2116315ce43ced2179724ab593e
# Successfully built mysqlclient
# ...

# %%
import pandas as pd
import sqlalchemy as db

# %%
engine = db.create_engine("mysql://root@127.0.0.1:3310/retail_db")
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3304, in Engine.raw_connection(self)
#    3283 """Return a "raw" DBAPI connection from the connection pool.
#    3284
#    3285 The returned object is a proxied version of the DBAPI
#    (...)
#    3302
#    3303 """
# -> 3304 return self.pool.connect()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
# ...
