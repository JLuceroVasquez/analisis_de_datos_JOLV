# %%
# Instalamos la librería de mongo
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 18.1 MB/s eta 0:00:00
# ...

# %%
# Traemos la libreía de pandas, mongocliente, sqlalchemy
import pandas as pd
from pymongo import MongoClient
import sqlalchemy as db

# %%
#Vinculo al motor de BD para escribir SQL en Phyton
engine = db.create_engine("mysql://root:root@127.0.0.1:3310/retail_db")
#Obtiene la conexión "mysql://user:password@servidor/database""
conn = engine.connect()

# %%
#Creamos un dataframe
customer_df = pd.read_sql('customers',con=conn)
customer_df.head()
# Out:
#    customer_id customer_fname customer_lname customer_email customer_password  \
# 0            1        Richard      Hernandez      XXXXXXXXX         XXXXXXXXX
# 1            2           Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2            3            Ann          Smith      XXXXXXXXX         XXXXXXXXX
# 3            4           Mary          Jones      XXXXXXXXX         XXXXXXXXX
# 4            5         Robert         Hudson      XXXXXXXXX         XXXXXXXXX
#
#            customer_street customer_city customer_state customer_zipcode
# 0       6303 Heather Plaza   Brownsville             TX            78521
# 1  9526 Noble Embers Ridge     Littleton             CO            80126
# 2   3422 Blue Pioneer Bend        Caguas             PR            00725
# 3       8324 Little Common    San Marcos             CA            92069
# 4   10 Crystal River Mall         Caguas             PR            00725

# %%
#Creamos una cadena de conexión "servidor://usuario:contraseña@permisos"
connection_string = "mongodb+srv://jimmylucero:jimmylucero123@jolv0.mnwru.mongodb.net/?retryWrites=true&w=majority&appName=JOLV0"
#Creamos una variable desde la que se acceda la cadena de conexión
client = MongoClient(connection_string)

# %%
#Crearemos una base de datos a partir de una bd existente en Mongo DB (reatil_db que aún no existe pero existirpa cuando insertemos datos)
db_name= client['reatil_db']
#Creamos una conexión a partir de una tabla existente en reatil_db
collection_name = db_name['customers']

# %%
#Insertamos registros en nuestra colección pero no podemos hacer a partir de un dataframe. Si ejecutamos lo siguiente sale error:
#collection_name.insert_many(customer_df)
#Mongo trabaja con documentos, y podemos insertar datos a partir de diccionarios.
#Vamos a convertir el df a diccionarios
df_to_dict = customer_df.to_dict('records')
collection_name.insert_many(df_to_dict)
# Out:
# InsertManyResult([ObjectId('66eccf5a45306f8c0a78ab8a'), ObjectId('66eccf5a45306f8c0a78ab8b'), ObjectId('66eccf5a45306f8c0a78ab8c'), ObjectId('66eccf5a45306f8c0a78ab8d'), ObjectId('66eccf5a45306f8c0a78ab8e'), ObjectId('66eccf5a45306f8c0a78ab8f'), ObjectId('66eccf5a45306f8c0a78ab90'), ObjectId('66eccf5a45306f8c0a78ab91'), ObjectId('66eccf5a45306f8c0a78ab92'), ObjectId('66eccf5a45306f8c0a78ab93'), ObjectId('66eccf5a45306f8c0a78ab94'), ObjectId('66eccf5a45306f8c0a78ab95'), ObjectId('66eccf5a45306f8c0a78ab96'), ObjectId('66eccf5a45306f8c0a78ab97'), ObjectId('66eccf5a45306f8c0a78ab98'), ObjectId('66eccf5a45306f8c0a78ab99'), ObjectId('66eccf5a45306f8c0a78ab9a'), ObjectId('66eccf5a45306f8c0a78ab9b'), ObjectId('66eccf5a45306f8c0a78ab9c'), ObjectId('66eccf5a45306f8c0a78ab9d'), ObjectId('66eccf5a45306f8c0a78ab9e'), ObjectId('66eccf5a45306f8c0a78ab9f'), ObjectId('66eccf5a45306f8c0a78aba0'), ObjectId('66eccf5a45306f8c0a78aba1'), ObjectId('66eccf5a45306f8c0a78aba2'), ObjectId('66eccf5a45306f8c0a78
# ...

# %%
# Filtramos los objetos de nuestro interés con find
customers = collection_name.find({'customer_state':'NY'})
customers

# %%
#Convertirmos los diccionarios que están dentro de los objetos filtrados en un dataframe
customers_df = pd.DataFrame(customers)
customers_df.head()
# Out:
#                         _id  customer_id customer_fname customer_lname  \
# 0  66eccf5a45306f8c0a78abb2           41       Victoria          Mason
# 1  66eccf5a45306f8c0a78abb7           46       Jennifer          Smith
# 2  66eccf5a45306f8c0a78abc5           60           Mary      Gutierrez
# 3  66eccf5a45306f8c0a78abc7           62           Mary          Oneal
# 4  66eccf5a45306f8c0a78abda           81           Mary          Smith
#
#   customer_email customer_password           customer_street customer_city  \
# 0      XXXXXXXXX         XXXXXXXXX  7869 Crystal View Villas      Brooklyn
# 1      XXXXXXXXX         XXXXXXXXX      5463 Rocky Autoroute      Freeport
# 2      XXXXXXXXX         XXXXXXXXX         8632 Bright Route       Webster
# 3      XXXXXXXXX         XXXXXXXXX   2659 Jagged Rabbit View      Brooklyn
# 4      XXXXXXXXX         XXXXXXXXX          8434 Honey Pines        Ithaca
#
#   customer_state customer_zipcode
# 0             NY            11230
# ...
